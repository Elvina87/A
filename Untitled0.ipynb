# %% [markdown]
# <a href="https://colab.research.google.com/github/Elvina87/A/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame({"x":[1,3,2],"y":[2,4,1]})

# %%
df
# Out:
#    x  y
# 0  1  2
# 1  3  4
# 2  2  1

# %%
df.drop(1, axis=0, inplace=True)

# %%
df
# Out:
#    x  y
# 0  1  2
# 2  2  1

# %%
del df["x"]

# %%
df
# Out:
#    y
# 0  2
# 2  1

# %%
df.reset_index(drop=True)
# Out:
#    y
# 0  2
# 1  1

# %%
df1=pd.DataFrame({"x":[1,3,2],"y":[2,4,1]})
df2=pd.DataFrame({"x":[3,1,2],"y":[0,2,2]})
print(df1>=df2)
# Out:
#        x      y
# 0  False   True
# 1   True   True
# 2   True  False

# %%
df1[df1>1]
# Out:
#      x    y
# 0  NaN  2.0
# 1  3.0  4.0
# 2  2.0  NaN

# %%
df2[(df2<2)&(df2>0)]
# Out:
#      x   y
# 0  NaN NaN
# 1  1.0 NaN
# 2  NaN NaN

# %%
df2[(df2<1)|(df2>2)]
# Out:
#      x    y
# 0  3.0  0.0
# 1  NaN  NaN
# 2  NaN  NaN

# %%
data = {"Имя":['Анна','Борис',None,'Джон'],"Возраст":[25,30,28,None]}
df=pd.DataFrame(data)

# %%
df
# Out:
#      Имя  Возраст
# 0   Анна     25.0
# 1  Борис     30.0
# 2   None     28.0
# 3   Джон      NaN

# %%
df[df==isnull]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-0562b847f578> in <cell line: 1>()
# ----> 1 df[df==isnull]
#
# NameError: name 'isnull' is not defined

# %%
df.isnull().loc[df['Имя']==True]
# Out:
# Empty DataFrame
# Columns: [Имя, Возраст]
# Index: []
